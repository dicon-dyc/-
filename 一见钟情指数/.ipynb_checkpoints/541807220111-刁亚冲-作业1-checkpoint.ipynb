# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pivottablejs import pivot_ui
from

# %%
train_data = pd.read_csv('./used_car_train_20200313.csv',sep=' ')
text_data = pd.read_csv('./used_car_testB_20200421.csv',sep=' ',index_col=0)

# %%
train_data.shape,text_data.shape
# Out:
# ((150000, 31), (50000, 29))

# %%
pivot_ui(train_data)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
train_data.columns
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'notRepairedDamage', 'regionCode',
#        'seller', 'offerType', 'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3',
#        'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12',
#        'v_13', 'v_14'],
#       dtype='object')

# %%
text_data.columns
# Out:
# Index(['name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType', 'gearbox',
#        'power', 'kilometer', 'notRepairedDamage', 'regionCode', 'seller',
#        'offerType', 'creatDate', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5',
#        'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13', 'v_14'],
#       dtype='object')

# %%
train_data.head()
# Out:
#    SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  power  \
# 0       0     736  20040402   30.0      6       1.0       0.0      0.0     60
# 1       1    2262  20030301   40.0      1       2.0       0.0      0.0      0
# 2       2   14874  20040403  115.0     15       1.0       0.0      0.0    163
# 3       3   71865  19960908  109.0     10       0.0       0.0      1.0    193
# 4       4  111080  20120103  110.0      5       1.0       0.0      0.0     68
#
#    kilometer  ...       v_5       v_6       v_7       v_8       v_9      v_10  \
# 0       12.5  ...  0.235676  0.101988  0.129549  0.022816  0.097462 -2.881803
# 1       15.0  ...  0.264777  0.121004  0.135731  0.026597  0.020582 -4.900482
# 2       12.5  ...  0.251410  0.114912  0.165147  0.062173  0.027075 -4.846749
# 3       15.0  ...  0.274293  0.110300  0.121964  0.033395  0.000000 -4.509599
# 4        5.0  ...  0.228036  0.073205  0.091880  0.078819  0.121534 -1.896240
#
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 31 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SaleID             150000 non-null  int64
#  1   name               150000 non-null  int64
#  2   regDate            150000 non-null  int64
#  3   model              149999 non-null  float64
#  4   brand              150000 non-null  int64
#  5   bodyType           145494 non-null  float64
#  6   fuelType           141320 non-null  float64
#  7   gearbox            144019 non-null  float64
#  8   power              150000 non-null  int64
#  9   kilometer          150000 non-null  float64
#  10  notRepairedDamage  150000 non-null  object
#  11  regionCode         150000 non-null  int64
#  12  seller             150000 non-null  int64
#  13  offerType          150000 non-null  int64
#  14  creatDate          150000 non-null  int64
# ...

# %%
train_data.columns
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'notRepairedDamage', 'regionCode',
#        'seller', 'offerType', 'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3',
#        'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12',
#        'v_13', 'v_14'],
#       dtype='object')

# %%
train_data.describe()
# Out:
#               SaleID           name       regDate          model  \
# count  150000.000000  150000.000000  1.500000e+05  149999.000000
# mean    74999.500000   68349.172873  2.003417e+07      47.129021
# std     43301.414527   61103.875095  5.364988e+04      49.536040
# min         0.000000       0.000000  1.991000e+07       0.000000
# 25%     37499.750000   11156.000000  1.999091e+07      10.000000
# 50%     74999.500000   51638.000000  2.003091e+07      30.000000
# 75%    112499.250000  118841.250000  2.007111e+07      66.000000
# max    149999.000000  196812.000000  2.015121e+07     247.000000
#
#                brand       bodyType       fuelType        gearbox  \
# count  150000.000000  145494.000000  141320.000000  144019.000000
# mean        8.052733       1.792369       0.375842       0.224943
# std         7.864956       1.760640       0.548677       0.417546
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
text_data.describe()
# Out:
#                 name       regDate        model         brand      bodyType  \
# count   50000.000000  5.000000e+04  50000.00000  50000.000000  48496.000000
# mean    68505.606100  2.003401e+07     47.64948      8.087140      1.793736
# std     61032.124271  5.351615e+04     49.90741      7.899648      1.764970
# min         1.000000  1.991000e+07      0.00000      0.000000      0.000000
# 25%     11315.000000  1.999100e+07     11.00000      1.000000      0.000000
# 50%     52215.000000  2.003091e+07     30.00000      6.000000      1.000000
# 75%    118710.750000  2.007110e+07     66.00000     13.000000      3.000000
# max    196808.000000  2.015121e+07    246.00000     39.000000      7.000000
#
#            fuelType       gearbox         power     kilometer    regionCode  \
# count  47076.000000  48032.000000  50000.000000  50000.000000  50000.000000
# mean       0.376498      0.226953    119.766960     12.598260   2581.080680
# ...

# %%
numerical_cols = train_data.select_dtypes(exclude = 'object').columns
print(numerical_cols)
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'regionCode', 'seller', 'offerType',
#        'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5', 'v_6',
#        'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13', 'v_14'],
#       dtype='object')

# %%
numerical_cols1 = train_data.select_dtypes(exclude = 'object').columns
print(numerical_cols1)
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'regionCode', 'seller', 'offerType',
#        'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5', 'v_6',
#        'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13', 'v_14'],
#       dtype='object')

# %%
categorical_cols = train_data.select_dtypes(include = 'object').columns
print(categorical_cols)
# Out:
# Index(['notRepairedDamage'], dtype='object')

# %%
train_data.isnull().sum()
# Out:
# SaleID                  0
# name                    0
# regDate                 0
# model                   1
# brand                   0
# bodyType             4506
# fuelType             8680
# gearbox              5981
# power                   0
# kilometer               0
# notRepairedDamage       0
# regionCode              0
# seller                  0
# offerType               0
# creatDate               0
# price                   0
# v_0                     0
# v_1                     0
# v_2                     0
# v_3                     0
# v_4                     0
# v_5                     0
# v_6                     0
# v_7                     0
# v_8                     0
# v_9                     0
# v_10                    0
# v_11                    0
# v_12                    0
# v_13                    0
# v_14                    0
# dtype: int64

# %%
feature_cols = [col for col in numerical_cols if col not in ['SaleID','name','regDate','creatDate','price','model','brand',
                                                             'regionCode','seller']]
feature_cols = [col for col in feature_cols if 'Type' not in col]

feature_cols1 = [col for col in numerical_cols1 if col not in ['SaleID','name','regDate','creatDate','price','model','brand',
                                                             'regionCode','seller']]
feature_cols1 = [col for col in feature_cols1 if 'Type' not in col]

# %%
X_data = train_data[feature_cols]
Y_data = train_data['price']
text_data = text_data[feature_cols1]
print(X_data.shape)
print(text_data.shape)
# Out:
# (150000, 18)
# (50000, 18)

# %%
text_data.head()
# Out:
#         gearbox  power  kilometer        v_0       v_1       v_2       v_3  \
# SaleID
# 200000      0.0    101       15.0  42.142061 -3.094739 -0.721300  1.466344
# 200001      0.0     73        6.0  43.907034 -3.244605 -0.766430  1.276718
# 200002      0.0    120        5.0  45.389665  3.372384 -0.965565 -2.447316
# 200003      0.0     58       15.0  42.788775  4.035052 -0.217403  1.708806
# 200004      0.0    116       15.0  43.670763 -3.135382 -1.134107  0.470315
#
#              v_4       v_5       v_6       v_7       v_8       v_9      v_10  \
# SaleID
# 200000  1.009846  0.236520  0.000241  0.105319  0.046233  0.094522  3.619512
# 200001 -1.065338  0.261518  0.000000  0.120323  0.046784  0.035385  2.997376
# 200002  0.624268  0.261691  0.090836  0.000000  0.079655  0.073586 -3.951084
# 200003  1.119165  0.236050  0.101777  0.098950  0.026830  0.096614 -2.846788
# 200004  0.134032  0.257000  0.000000  0.066732  0.057771  0.068852  2.839010
#
# ...

# %%
Y_data.head()
# Out:
# 0    1850
# 1    3600
# 2    6222
# 3    2400
# 4    5200
# Name: price, dtype: int64

# %%
X_data = X_data.fillna(-1)
text_data = text_data.fillna(-1)

# %%
X_data_max = X_data.max().copy()
X_data_min = X_data.min().copy()
Y_data_max = Y_data.max().copy()
Y_data_min = Y_data.min().copy()

# %%
X_data = (X_data - X_data.min())/(X_data.max()-X_data.min())
Y_data = (Y_data - Y_data.min())/(Y_data.max()-Y_data.min())
text_data = (text_data - text_data.min())/(text_data.max()-text_data.min())

# %%
X_data.head()
# Out:
#    gearbox     power  kilometer       v_0       v_1       v_2       v_3  \
# 0      0.5  0.003107   0.827586  0.590596  0.711261  0.192329  0.550784
# 1      0.5  0.000000   1.000000  0.679716  0.820574  0.196059  0.505302
# 2      0.5  0.008440   0.827586  0.710518  0.785078  0.246327  0.366414
# 3      1.0  0.009994   1.000000  0.697207  0.756563  0.188038  0.476285
# 4      0.5  0.003521   0.310345  0.637535  0.544686  0.214533  0.332976
#
#         v_4       v_5       v_6       v_7       v_8       v_9      v_10  \
# 0  0.492084  0.807557  0.673547  0.092210  0.141901  0.437465  0.292048
# 1  0.262857  0.907274  0.799128  0.096610  0.165416  0.092382  0.198266
# 2  0.300847  0.861471  0.758900  0.117548  0.386669  0.121528  0.200762
# 3  0.190861  0.939881  0.728440  0.086811  0.207689  0.000000  0.216425
# 4  0.590558  0.781377  0.483458  0.065398  0.490198  0.545516  0.337834
#
#        v_11      v_12      v_13      v_14
# 0  0.343037  0.307346  0.323443  0.490716
# ...

# %%
X_data.describe()
# Out:
#              gearbox          power      kilometer            v_0  \
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean        0.588050       0.006178       0.834287       0.638576
# std         0.237085       0.009174       0.270316       0.112462
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.500000       0.003884       0.827586       0.580437
# 50%         0.500000       0.005696       1.000000       0.647911
# 75%         0.500000       0.007767       1.000000       0.711724
# max         1.000000       1.000000       1.000000       1.000000
#
#                  v_1            v_2            v_3            v_4  \
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean        0.365945       0.193627       0.429304       0.391502
# std         0.313527       0.124632       0.118304       0.106635
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
Y_data.head()
# Out:
# 0    0.018392
# 1    0.035894
# 2    0.062117
# 3    0.023893
# 4    0.051896
# Name: price, dtype: float64

# %%
plt.scatter(X_data['power'],Y_data)
plt.show()

# %%
X_data.head()
# Out:
#    gearbox     power  kilometer       v_0       v_1       v_2       v_3  \
# 0      0.5  0.003107   0.827586  0.590596  0.711261  0.192329  0.550784
# 1      0.5  0.000000   1.000000  0.679716  0.820574  0.196059  0.505302
# 2      0.5  0.008440   0.827586  0.710518  0.785078  0.246327  0.366414
# 3      1.0  0.009994   1.000000  0.697207  0.756563  0.188038  0.476285
# 4      0.5  0.003521   0.310345  0.637535  0.544686  0.214533  0.332976
#
#         v_4       v_5       v_6       v_7       v_8       v_9      v_10  \
# 0  0.492084  0.807557  0.673547  0.092210  0.141901  0.437465  0.292048
# 1  0.262857  0.907274  0.799128  0.096610  0.165416  0.092382  0.198266
# 2  0.300847  0.861471  0.758900  0.117548  0.386669  0.121528  0.200762
# 3  0.190861  0.939881  0.728440  0.086811  0.207689  0.000000  0.216425
# 4  0.590558  0.781377  0.483458  0.065398  0.490198  0.545516  0.337834
#
#        v_11      v_12      v_13      v_14
# 0  0.343037  0.307346  0.323443  0.490716
# ...

# %%
X_data.shape
# Out:
# (150000, 18)

# %%
Y_data.head()
# Out:
# 0    0.018392
# 1    0.035894
# 2    0.062117
# 3    0.023893
# 4    0.051896
# Name: price, dtype: float64

# %%
Y_data.shape
# Out:
# (150000,)

# %%
def computeCost(X,y,theta):
    inner = np.power(((X*theta.T)-y),2)
    return np.sum(inner)/(2*len(X))

# %%
X_data.insert(0,'Ones',1)
X_data.shape
# Out:
# (150000, 19)

# %%
X_data.head()
# Out:
#    Ones  gearbox     power  kilometer       v_0       v_1       v_2       v_3  \
# 0     1      0.5  0.003107   0.827586  0.590596  0.711261  0.192329  0.550784
# 1     1      0.5  0.000000   1.000000  0.679716  0.820574  0.196059  0.505302
# 2     1      0.5  0.008440   0.827586  0.710518  0.785078  0.246327  0.366414
# 3     1      1.0  0.009994   1.000000  0.697207  0.756563  0.188038  0.476285
# 4     1      0.5  0.003521   0.310345  0.637535  0.544686  0.214533  0.332976
#
#         v_4       v_5       v_6       v_7       v_8       v_9      v_10  \
# 0  0.492084  0.807557  0.673547  0.092210  0.141901  0.437465  0.292048
# 1  0.262857  0.907274  0.799128  0.096610  0.165416  0.092382  0.198266
# 2  0.300847  0.861471  0.758900  0.117548  0.386669  0.121528  0.200762
# 3  0.190861  0.939881  0.728440  0.086811  0.207689  0.000000  0.216425
# 4  0.590558  0.781377  0.483458  0.065398  0.490198  0.545516  0.337834
#
#        v_11      v_12      v_13      v_14
# ...

# %%
X_data = np.matrix(X_data.values)
Y_data = np.matrix(Y_data.values)

# %%
theta = np.matrix(np.zeros((1,19)))

# %%
theta.shape
# Out:
# (1, 19)

# %%
def gradientDescent(X_data,Y_data,theta,alpha,iters):
    temp = np.matrix(np.zeros(theta.shape))
    parameters = int(theta.ravel().shape[1])
    cost = np.zeros(iters)
    
    for i in range(iters):
        error  = (X_data * theta.T) - Y_data
        
        for j in range(parameters):
            term = np.multiply(error,X_data[:,j])
            temp[0,j] = theta[0,j] - ((alpha/len(X_data))*np.sum(term))
        
        theta = temp
        cost[i] = computeCost(X_data,Y_data,theta)
    return theta, cost

# %%
alpha = 0.06
iters = 1000

# %%
g,cost = gradientDescent(X_data,Y_data.T,theta,alpha,iters)
g
# Out:
# matrix([[ 0.00717863,  0.034235  ,  0.00351942, -0.06151076,  0.07622943,
#           0.00568451,  0.02679126, -0.07181158, -0.01881915,  0.01819029,
#           0.01209139,  0.0136093 ,  0.12021864, -0.03653094, -0.02828731,
#          -0.02703094,  0.08251174, -0.01258161, -0.00087471]])

# %%
computeCost(X_data,Y_data.T,g)
# Out:
# 0.001004740460064439

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.plot(np.arange(iters),cost,'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Error vs. Training Epoch')
plt.show()

# %%
train_data.v_5.shape
# Out:
# (150000,)

# %%
train_data.v_5.head()
# Out:
# 0    0.235676
# 1    0.264777
# 2    0.251410
# 3    0.274293
# 4    0.228036
# Name: v_5, dtype: float64

# %%
text_data.head()
# Out:
#         gearbox     power  kilometer       v_0       v_1       v_2       v_3  \
# SaleID
# 200000      0.5  0.005257   1.000000  0.536126  0.099550  0.144590  0.478515
# 200001      0.5  0.003800   0.379310  0.621995  0.086429  0.142619  0.466030
# 200002      0.5  0.006246   0.310345  0.694127  0.665718  0.133923  0.220831
# 200003      0.5  0.003019   1.000000  0.567590  0.723732  0.166596  0.494479
# 200004      0.5  0.006038   1.000000  0.610500  0.095991  0.126562  0.412934
#
#              v_4       v_5       v_6       v_7       v_8       v_9      v_10  \
# SaleID
# 200000  0.570393  0.812292  0.001570  0.074612  0.293624  0.447328  0.598154
# 200001  0.344651  0.898147  0.000000  0.085242  0.297122  0.167461  0.568942
# 200002  0.528449  0.898738  0.592145  0.000000  0.505884  0.348248  0.242686
# 200003  0.582285  0.810678  0.663463  0.070100  0.170392  0.457225  0.294537
# 200004  0.475121  0.882627  0.000000  0.047275  0.366899  0.325845  0.561506
#
# ...

# %%
x = np.linspace(train_data.v_12.min(),train_data.v_12.max(),100)
f = g[0,0] + g[0,16]*x
fig,ax = plt.subplots(figsize = (12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(train_data.v_12.tolist(),Y_data.tolist(),label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('Population')
ax.set_ylabel('Profit')
ax.set_title('Predicted Profit vs. Population Size')
plt.show()

# %%
real_y = abs(g[0,0] + g[0,1]*text_data['gearbox'] + g[0,2]*text_data['power'] + g[0,3]*text_data['kilometer'] + g[0,4]*text_data['v_0'] + g[0,5]*text_data['v_1'] + g[0,6]*text_data['v_2']+g[0,7]*text_data['v_3']+g[0,8]*text_data['v_4'] + g[0,9]*text_data['v_5'] + g[0,10]*text_data['v_6']+g[0,11]*text_data['v_7'] + g[0,12]*text_data['v_8'] + g[0,13]*text_data['v_9']+g[0,14]*text_data['v_10']+g[0,15]*text_data['v_11']+g[0,16]*text_data['v_12']+g[0,17]*text_data['v_13']+g[0,18]*text_data['v_14'])
real_y
# Out:
# SaleID
# 200000    0.008501
# 200001    0.062534
# 200002    0.125575
# 200003    0.007438
# 200004    0.025074
#             ...
# 249995    0.094555
# 249996    0.168178
# 249997    0.097027
# 249998    0.087327
# 249999    0.095486
# Length: 50000, dtype: float64

# %%
real = real_y*(Y_data_max-Y_data_min) + Y_data_min

# %%
real.to_csv('./submit.csv')
